# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
from datetime import datetime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 614

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Dimension Lists To Store Data
city_list = [None]*len(cities)
cloudiness_list = [None]*len(cities)
country_list = [None]*len(cities)
date_list = [None]*len(cities)
humidity_list = [None]*len(cities)
lat_list = [None]*len(cities)
lng_list = [None]*len(cities)
max_temp_list = [None]*len(cities)
wind_speed_list = [None]*len(cities)

city_index = 0
url = "http://api.openweathermap.org/data/2.5/weather?"

#Go through list of cities
for city in cities:
    # Build query URL
    query_url = url + "appid=" + api_key + "&q=" + city
    #Make Request
    weather_response = requests.get(query_url)
    #If Request Successful
    if weather_response.status_code == 200:
        print(f'Found city {city}, index = {city_index}')
        #Convert Response to Json
        weather_json = weather_response.json()
        #Filter out Humidity bugs
        if weather_json['main']['humidity'] <= 100:
            city_list[city_index] = city
            cloudiness_list[city_index] = weather_json['clouds']['all']
            country_list[city_index] = weather_json['sys']['country']
            date_list[city_index] = datetime.fromtimestamp(weather_json['dt'])
            humidity_list[city_index] = weather_json['main']['humidity']
            lat_list[city_index] = weather_json['coord']['lat']
            lng_list[city_index] = weather_json['coord']['lon']
            max_temp_list[city_index] = (weather_json['main']['temp_max']-273.15)*(9/5)+32
            wind_speed_list[city_index] = weather_json['wind']['speed']*2.23694
            city_index += 1
        else:
            print('City has data bug. Skipping...')                    
    else:
        print('City not found. Skipping...')
    
print('Done')
TodayDate = datetime.today().strftime('%Y-%m-%d')
# Out:
# Found city hermanus, index = 0
# Found city eyrarbakki, index = 1
# Found city arraial do cabo, index = 2
# Found city vardo, index = 3
# Found city chokurdakh, index = 4
# Found city ormara, index = 5
# Found city qaanaaq, index = 6
# Found city yellowknife, index = 7
# Found city kodiak, index = 8
# Found city muskogee, index = 9
# Found city cape town, index = 10
# Found city ahipara, index = 11
# Found city felanitx, index = 12
# Found city broome, index = 13
# Found city tuktoyaktuk, index = 14
# Found city rikitea, index = 15
# City not found. Skipping...
# Found city kenai, index = 16
# Found city karratha, index = 17
# City not found. Skipping...
# Found city avarua, index = 18
# Found city dikson, index = 19
# Found city sao filipe, index = 20
# Found city topolobampo, index = 21
# Found city anadyr, index = 22
# Found city bagdarin, index = 23
# Found city victor harbor, index = 24
# Found city punta arenas, index = 25
# Found city padang, index = 26
# Found city longyearbyen, index = 27
# Found city codrington, index = 28
# Found city tessalit, index = 29
# City not found. Skipping...
# City not found. Skipping...
# Found city vaini, index = 30
# Found city acajutla, index = 31
# Found city namibe, index = 32
# Found city los llanos de aridane, index = 33
# Found city east london, index = 34
# Found city mackay, index = 35
# Found city castro, index = 36
# Found city mataura, index = 37
# Found city bluff, index = 38
# Found city vostok, index = 39
# Found city atuona, index = 40
# Found city flin flon, index = 41
# Found city ushuaia, index = 42
# Found city zambezi, index = 43
# Found city bosobolo, index = 44
# Found city sur, index = 45
# Found city saldanha, index = 46
# Found city batouri, index = 47
# Found city hilo, index = 48
# Found city sechura, index = 49
# Found city jamestown, index = 50
# Found city chapais, index = 51
# Found city busselton, index = 52
# Found city new norfolk, index = 53
# Found city sitka, index = 54
# Found city touros, index = 55
# Found city port alfred, index = 56
# City not found. Skipping...
# Found city butaritari, index = 57
# Found city leh, index = 58
# Found city hithadhoo, index = 59
# City not found. Skipping...
# City not found. Skipping...
# Found city thompson, index = 60
# Found city georgetown, index = 61
# Found city oranjemund, index = 62
# City not found. Skipping...
# Found city raudeberg, index = 63
# Found city mairi, index = 64
# Found city yazykovo, index = 65
# Found city upernavik, index = 66
# Found city puerto leguizamo, index = 67
# Found city penzance, index = 68
# Found city srinivaspur, index = 69
# Found city port hardy, index = 70
# Found city nome, index = 71
# Found city cherskiy, index = 72
# Found city lompoc, index = 73
# Found city paamiut, index = 74
# Found city mazagao, index = 75
# Found city barrow, index = 76
# City not found. Skipping...
# Found city muzhi, index = 77
# Found city tasiilaq, index = 78
# Found city provideniya, index = 79
# Found city kapaa, index = 80
# City not found. Skipping...
# Found city salvador, index = 81
# City not found. Skipping...
# Found city khatanga, index = 82
# Found city vila franca do campo, index = 83
# Found city westport, index = 84
# Found city lebu, index = 85
# Found city mpanda, index = 86
# Found city novoraychikhinsk, index = 87
# Found city yushu, index = 88
# Found city demba, index = 89
# Found city orsha, index = 90
# Found city emmett, index = 91
# Found city tiksi, index = 92
# Found city iwanai, index = 93
# Found city vanimo, index = 94
# Found city eureka, index = 95
# Found city belmonte, index = 96
# Found city mar del plata, index = 97
# Found city altay, index = 98
# Found city hobart, index = 99
# Found city faya, index = 100
# Found city harrison, index = 101
# Found city ketchikan, index = 102
# Found city tulun, index = 103
# Found city khor, index = 104
# City not found. Skipping...
# Found city abu dhabi, index = 105
# Found city rocha, index = 106
# Found city dandong, index = 107
# Found city talnakh, index = 108
# Found city nanortalik, index = 109
# Found city mayo, index = 110
# Found city isla mujeres, index = 111
# Found city rio grande, index = 112
# Found city roald, index = 113
# Found city narsipatnam, index = 114
# Found city maragogi, index = 115
# Found city hasaki, index = 116
# Found city merauke, index = 117
# Found city vryburg, index = 118
# Found city saint-philippe, index = 119
# Found city beringovskiy, index = 120
# Found city mahebourg, index = 121
# Found city portland, index = 122
# Found city concarneau, index = 123
# City not found. Skipping...
# Found city inirida, index = 124
# Found city suluq, index = 125
# Found city japura, index = 126
# Found city nouadhibou, index = 127
# City not found. Skipping...
# Found city kieta, index = 128
# Found city bandarbeyla, index = 129
# Found city husavik, index = 130
# Found city saint-augustin, index = 131
# Found city kavieng, index = 132
# Found city samarai, index = 133
# Found city huarmey, index = 134
# Found city mastung, index = 135
# Found city shellbrook, index = 136
# Found city vao, index = 137
# Found city lavrentiya, index = 138
# City not found. Skipping...
# Found city esperance, index = 139
# Found city salalah, index = 140
# Found city okitipupa, index = 141
# Found city kuching, index = 142
# Found city valparaiso, index = 143
# Found city nemuro, index = 144
# Found city egvekinot, index = 145
# Found city coquimbo, index = 146
# Found city tupik, index = 147
# City not found. Skipping...
# City not found. Skipping...
# Found city san patricio, index = 148
# Found city polyarnyy, index = 149
# City not found. Skipping...
# Found city kondinskoye, index = 150
# Found city yeppoon, index = 151
# Found city nikolskoye, index = 152
# Found city cabinda, index = 153
# Found city lata, index = 154
# Found city zeya, index = 155
# Found city sinnamary, index = 156
# Found city jalu, index = 157
# Found city bethel, index = 158
# Found city petropavlovsk-kamchatskiy, index = 159
# Found city nanga eboko, index = 160
# Found city wanaka, index = 161
# Found city geraldton, index = 162
# Found city ust-nera, index = 163
# Found city thinadhoo, index = 164
# Found city atar, index = 165
# Found city aklavik, index = 166
# Found city laguna, index = 167
# City not found. Skipping...
# Found city matay, index = 168
# City not found. Skipping...
# Found city zunheboto, index = 169
# Found city pagudpud, index = 170
# Found city hirara, index = 171
# Found city manaus, index = 172
# Found city metro, index = 173
# Found city nakhon phanom, index = 174
# Found city marsa matruh, index = 175
# Found city ganzhou, index = 176
# Found city tateyama, index = 177
# Found city kamina, index = 178
# Found city hami, index = 179
# City not found. Skipping...
# Found city cabo san lucas, index = 180
# Found city kruisfontein, index = 181
# Found city chabahar, index = 182
# Found city carnarvon, index = 183
# Found city tigil, index = 184
# Found city sorland, index = 185
# Found city tommot, index = 186
# Found city teluk intan, index = 187
# Found city puerto ayora, index = 188
# Found city ancud, index = 189
# Found city port elizabeth, index = 190
# Found city panzhihua, index = 191
# Found city albany, index = 192
# Found city rawson, index = 193
# Found city melilla, index = 194
# Found city barra do bugres, index = 195
# Found city nioki, index = 196
# Found city kahului, index = 197
# Found city bambous virieux, index = 198
# City not found. Skipping...
# Found city mosquera, index = 199
# Found city qeshm, index = 200
# Found city luba, index = 201
# Found city pevek, index = 202
# Found city vila, index = 203
# Found city churapcha, index = 204
# Found city faanui, index = 205
# Found city yazoo city, index = 206
# Found city kloulklubed, index = 207
# Found city bilibino, index = 208
# Found city berlevag, index = 209
# Found city svetlogorsk, index = 210
# City not found. Skipping...
# Found city grand gaube, index = 211
# Found city kirksville, index = 212
# Found city manokwari, index = 213
# Found city hambantota, index = 214
# Found city cidreira, index = 215
# Found city tuxpan, index = 216
# Found city kokopo, index = 217
# Found city ca mau, index = 218
# Found city ribeira grande, index = 219
# Found city kaitangata, index = 220
# Found city okato, index = 221
# Found city atasu, index = 222
# Found city farragut, index = 223
# Found city clyde river, index = 224
# Found city longhua, index = 225
# Found city vinh, index = 226
# Found city trinidad, index = 227
# Found city boende, index = 228
# Found city ugoofaaru, index = 229
# Found city meulaboh, index = 230
# Found city eyl, index = 231
# Found city hay river, index = 232
# Found city acapulco, index = 233
# City not found. Skipping...
# Found city port hedland, index = 234
# Found city constantine, index = 235
# Found city te anau, index = 236
# Found city atrauli, index = 237
# Found city pundaguitan, index = 238
# Found city ust-kulom, index = 239
# Found city necochea, index = 240
# Found city finschhafen, index = 241
# Found city leo, index = 242
# Found city ulvik, index = 243
# Found city alta floresta, index = 244
# Found city tolaga bay, index = 245
# Found city mutis, index = 246
# Found city tucupita, index = 247
# Found city verkhoyansk, index = 248
# City not found. Skipping...
# Found city sao gabriel da cachoeira, index = 249
# Found city nuuk, index = 250
# Found city gangapur, index = 251
# Found city graham, index = 252
# Found city leningradskiy, index = 253
# Found city port-gentil, index = 254
# Found city fairbanks, index = 255
# Found city airai, index = 256
# Found city pierre, index = 257
# Found city dosso, index = 258
# Found city adilabad, index = 259
# Found city palana, index = 260
# Found city clemson, index = 261
# Found city porto belo, index = 262
# Found city vilyuysk, index = 263
# Found city elko, index = 264
# Found city sabha, index = 265
# Found city okha, index = 266
# Found city ilulissat, index = 267
# Found city naze, index = 268
# Found city nantucket, index = 269
# Found city oranjestad, index = 270
# Found city coihaique, index = 271
# City not found. Skipping...
# Found city kristiansund, index = 272
# Found city bambanglipuro, index = 273
# Found city srednekolymsk, index = 274
# Found city souillac, index = 275
# City not found. Skipping...
# Found city ryotsu, index = 276
# Found city severo-kurilsk, index = 277
# Found city manacapuru, index = 278
# City not found. Skipping...
# Found city turukhansk, index = 279
# Found city vrangel, index = 280
# Found city pangnirtung, index = 281
# Found city goderich, index = 282
# Found city fujin, index = 283
# City not found. Skipping...
# Found city gat, index = 284
# Found city lagoa, index = 285
# Found city batangafo, index = 286
# Found city janauba, index = 287
# City not found. Skipping...
# Found city guerrero negro, index = 288
# Found city athabasca, index = 289
# Found city isangel, index = 290
# Found city fort morgan, index = 291
# Found city kalengwa, index = 292
# Found city guangshui, index = 293
# Found city zyryanka, index = 294
# Found city bredasdorp, index = 295
# Found city boma, index = 296
# Found city cabanas, index = 297
# Found city umm kaddadah, index = 298
# Found city jos, index = 299
# Found city tiznit, index = 300
# Found city losinyy, index = 301
# Found city fallon, index = 302
# Found city rovaniemi, index = 303
# Found city vila velha, index = 304
# Found city gopalpur, index = 305
# Found city ponta do sol, index = 306
# Found city seoul, index = 307
# City has data bug. Skipping...
# Found city victoria, index = 307
# Found city budelsdorf, index = 308
# Found city merrill, index = 309
# Found city peterhead, index = 310
# Found city najran, index = 311
# City not found. Skipping...
# Found city mount gambier, index = 312
# Found city bastrop, index = 313
# Found city luderitz, index = 314
# Found city avera, index = 315
# Found city sao felix do xingu, index = 316
# Found city puerto del rosario, index = 317
# Found city ayagoz, index = 318
# Found city abu samrah, index = 319
# Found city deputatskiy, index = 320
# Found city cocobeach, index = 321
# Found city carbonia, index = 322
# Found city kholmogory, index = 323
# Found city blackwater, index = 324
# Found city caledonia, index = 325
# Found city taybad, index = 326
# Found city norman wells, index = 327
# Found city kimbe, index = 328
# Found city peniche, index = 329
# Found city jiwani, index = 330
# Found city menongue, index = 331
# Found city fier, index = 332
# Found city bathsheba, index = 333
# Found city kwinana, index = 334
# Found city tres arroyos, index = 335
# Found city abu zabad, index = 336
# Found city chuy, index = 337
# Found city back mountain, index = 338
# Found city taltal, index = 339
# Found city balabac, index = 340
# Found city itupiranga, index = 341
# Found city hualmay, index = 342
# Found city uchiza, index = 343
# Found city shiyan, index = 344
# City not found. Skipping...
# Found city srivardhan, index = 345
# Found city dustlik, index = 346
# Found city yelan, index = 347
# Found city nara, index = 348
# Found city liberia, index = 349
# Found city puerto escondido, index = 350
# Found city villarrica, index = 351
# Found city tadine, index = 352
# Found city hachinohe, index = 353
# Found city humberto de campos, index = 354
# Found city edson, index = 355
# Found city carutapera, index = 356
# Found city luoyang, index = 357
# Found city yumen, index = 358
# Found city milkovo, index = 359
# City not found. Skipping...
# Found city maceio, index = 360
# Found city yar-sale, index = 361
# Found city henties bay, index = 362
# Found city lisala, index = 363
# Found city sueyoshi, index = 364
# City not found. Skipping...
# Found city hagere hiywet, index = 365
# Found city vernon, index = 366
# Found city zhezkazgan, index = 367
# City not found. Skipping...
# Found city port lincoln, index = 368
# Found city belaya gora, index = 369
# Found city huntingdon, index = 370
# Found city mogoytuy, index = 371
# Found city vytegra, index = 372
# Found city izvoarele, index = 373
# Found city margate, index = 374
# Found city haimen, index = 375
# Found city paragominas, index = 376
# Found city mankapur, index = 377
# Found city tura, index = 378
# Found city camacha, index = 379
# Found city manadhoo, index = 380
# Found city guiratinga, index = 381
# Found city kalmunai, index = 382
# Found city christchurch, index = 383
# Found city esso, index = 384
# Found city nabari, index = 385
# Found city sorong, index = 386
# Found city saint george, index = 387
# Found city sioux lookout, index = 388
# Found city slave lake, index = 389
# Found city muisne, index = 390
# Found city oktyabrskiy, index = 391
# City not found. Skipping...
# Found city mildura, index = 392
# Found city pemba, index = 393
# Found city union, index = 394
# Found city gabu, index = 395
# Found city somogyvar, index = 396
# City not found. Skipping...
# Found city ranong, index = 397
# Found city poum, index = 398
# Found city katsuura, index = 399
# Found city wufeng, index = 400
# Found city alofi, index = 401
# Found city ilebo, index = 402
# Found city kathu, index = 403
# Found city vagur, index = 404
# Found city entre rios, index = 405
# Found city pisco, index = 406
# Found city xining, index = 407
# Found city lovozero, index = 408
# City not found. Skipping...
# Found city manakara, index = 409
# Found city chiredzi, index = 410
# Found city soma, index = 411
# Found city red bluff, index = 412
# Found city richards bay, index = 413
# Found city terney, index = 414
# Found city ostrovnoy, index = 415
# Found city challans, index = 416
# Found city ekhabi, index = 417
# Found city hofn, index = 418
# Found city samana, index = 419
# Found city pangody, index = 420
# Found city jinchang, index = 421
# Found city dalbandin, index = 422
# City not found. Skipping...
# Found city sao miguel do araguaia, index = 423
# Found city general roca, index = 424
# City not found. Skipping...
# Found city ninghai, index = 425
# Found city irece, index = 426
# Found city tuy hoa, index = 427
# Found city sistranda, index = 428
# Found city santa maria do suacui, index = 429
# Found city barcelos, index = 430
# Found city puerto madero, index = 431
# Found city sudak, index = 432
# Found city zabol, index = 433
# Found city villanueva de cordoba, index = 434
# Found city abrego, index = 435
# Found city kijang, index = 436
# Found city atambua, index = 437
# City not found. Skipping...
# Found city cabras, index = 438
# City not found. Skipping...
# Found city goundam, index = 439
# Found city fomboni, index = 440
# Found city narsaq, index = 441
# Found city suoyarvi, index = 442
# Found city cadiz, index = 443
# Found city priiskovyy, index = 444
# Found city savannah bight, index = 445
# Found city seymchan, index = 446
# Found city labuhan, index = 447
# Found city santa maria da boa vista, index = 448
# Found city grand-santi, index = 449
# Found city pitimbu, index = 450
# Found city klaksvik, index = 451
# Found city elizabeth city, index = 452
# Found city bealanana, index = 453
# Found city valleyview, index = 454
# Found city fort nelson, index = 455
# Found city nha trang, index = 456
# Found city engels, index = 457
# Found city camocim, index = 458
# Found city tomohon, index = 459
# Found city xuddur, index = 460
# City not found. Skipping...
# Found city batsfjord, index = 461
# Found city comodoro rivadavia, index = 462
# Found city nioro, index = 463
# Found city kalabo, index = 464
# Found city kinna, index = 465
# Found city somanda, index = 466
# Found city cuenca, index = 467
# Found city astana, index = 468
# Found city ambon, index = 469
# Found city morrope, index = 470
# Found city wheatley, index = 471
# Found city sao joao da barra, index = 472
# Found city buin, index = 473
# Found city qasigiannguit, index = 474
# Found city banda aceh, index = 475
# Found city carlsbad, index = 476
# Found city menomonie, index = 477
# Found city naica, index = 478
# Found city palomares, index = 479
# Found city bereda, index = 480
# Found city hobbs, index = 481
# Found city dawlatabad, index = 482
# Found city saskylakh, index = 483
# Found city chapleau, index = 484
# Found city morgan city, index = 485
# Found city tampakan, index = 486
# City not found. Skipping...
# Found city mandalgovi, index = 487
# Found city sabang, index = 488
# Found city sharanga, index = 489
# Found city boden, index = 490
# Found city siuna, index = 491
# Found city kyren, index = 492
# City not found. Skipping...
# Found city kattivakkam, index = 493
# Found city moose jaw, index = 494
# Found city iqaluit, index = 495
# Found city belyy yar, index = 496
# City not found. Skipping...
# Found city mengcheng, index = 497
# Found city hoi an, index = 498
# Found city mutoko, index = 499
# Found city kavaratti, index = 500
# Found city byumba, index = 501
# Found city iberia, index = 502
# Found city namatanai, index = 503
# Found city temir, index = 504
# City not found. Skipping...
# Found city mount isa, index = 505
# Found city lixourion, index = 506
# Found city neryungri, index = 507
# Found city verkhnyaya sinyachikha, index = 508
# Found city horodnytsya, index = 509
# Found city phan thiet, index = 510
# Found city ruwi, index = 511
# Found city ust-kuyga, index = 512
# Found city babstovo, index = 513
# Found city conceicao do araguaia, index = 514
# Found city gorontalo, index = 515
# Found city bouza, index = 516
# Found city tromso, index = 517
# City not found. Skipping...
# Found city teya, index = 518
# City not found. Skipping...
# Found city bichura, index = 519
# Found city whitehorse, index = 520
# Found city gueret, index = 521
# Found city parabel, index = 522
# Found city saint anthony, index = 523
# Found city takoradi, index = 524
# Found city platteville, index = 525
# Found city barao de melgaco, index = 526
# Found city san quintin, index = 527
# Found city ylivieska, index = 528
# Found city vaitape, index = 529
# City not found. Skipping...
# Found city bubaque, index = 530
# Found city villa carlos paz, index = 531
# Found city nyurba, index = 532
# Found city naantali, index = 533
# Found city gigmoto, index = 534
# City not found. Skipping...
# Found city blythe, index = 535
# Found city burns lake, index = 536
# Found city dunedin, index = 537
# Found city iralaya, index = 538
# Found city gosainganj, index = 539
# Found city niamey, index = 540
# Found city dongfeng, index = 541
# Found city lorengau, index = 542
# Found city sokoni, index = 543
# Found city saint-louis, index = 544
# Found city beloha, index = 545
# Found city magadan, index = 546
# Found city gamboma, index = 547
# Found city fortuna, index = 548
# Found city socorro, index = 549
# City not found. Skipping...
# Found city cayenne, index = 550
# Found city kudahuvadhoo, index = 551
# Found city flinders, index = 552
# Found city ust-ilimsk, index = 553
# Found city alekseyevsk, index = 554
# Found city batemans bay, index = 555
# Found city lazaro cardenas, index = 556
# City not found. Skipping...
# Found city luau, index = 557
# Found city sulangan, index = 558
# Found city pacific grove, index = 559
# Done

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data_dict = {'City':city_list,
                     'Cloudiness':cloudiness_list,
                     'Country':country_list,
                     'Date':date_list,
                     'Humidity':humidity_list,
                     'Lat':lat_list,
                     'Lng':lng_list,
                     'Max Temp':max_temp_list,
                     'Wind Speed':wind_speed_list                     
                    }
weather_data_df = pd.DataFrame(weather_data_dict)
weather_data_df = weather_data_df.dropna()
weather_data_df.to_csv(output_data_file)
weather_data_df
# Out:
#                  City  Cloudiness Country                Date  Humidity  \
# 0            hermanus         0.0      ZA 2019-08-24 13:45:40      94.0
# 1          eyrarbakki        40.0      IS 2019-08-24 13:46:35      76.0
# 2     arraial do cabo        20.0      BR 2019-08-24 13:45:44      69.0
# 3               vardo        90.0      US 2019-08-24 13:46:35      46.0
# 4          chokurdakh        94.0      RU 2019-08-24 13:46:35      69.0
# 5              ormara         8.0      PK 2019-08-24 13:46:35      78.0
# 6             qaanaaq        94.0      GL 2019-08-24 13:45:49      62.0
# 7         yellowknife        75.0      CA 2019-08-24 13:46:36      81.0
# 8              kodiak        75.0      US 2019-08-24 13:46:36      64.0
# 9            muskogee        90.0      US 2019-08-24 13:43:40      70.0
# 10          cape town        20.0      ZA 2019-08-24 13:40:52      93.0
# 11            ahipara       100.0      NZ 2019-08-24 13:46:36     100.0
# 12           felanitx        40.0      ES 2019-08-24 13:46:37      74.0
# 13             broome         0.0      GB 2019-08-24 13:46:37      68.0
# 14        tuktoyaktuk        90.0      CA 2019-08-24 13:46:37      93.0
# 15            rikitea        80.0      PF 2019-08-24 13:45:44      68.0
# 16              kenai        20.0      US 2019-08-24 13:46:37      58.0
# 17           karratha         0.0      AU 2019-08-24 13:46:38      60.0
# 18             avarua        47.0      CK 2019-08-24 13:44:44      83.0
# 19             dikson        83.0      RU 2019-08-24 13:46:38      97.0
# 20         sao filipe        80.0      CV 2019-08-24 13:46:38      84.0
# 21        topolobampo        90.0      MX 2019-08-24 13:46:39      70.0
# 22             anadyr        40.0      RU 2019-08-24 13:46:39      87.0
# 23           bagdarin         0.0      RU 2019-08-24 13:46:39      90.0
# 24      victor harbor        75.0      AU 2019-08-24 13:46:39      93.0
# 25       punta arenas        75.0      CL 2019-08-24 13:45:37      81.0
# 26             padang        91.0      ID 2019-08-24 13:46:40      81.0
# 27       longyearbyen        75.0      NO 2019-08-24 13:46:40      75.0
# 28         codrington        75.0      AU 2019-08-24 13:46:40     100.0
# 29           tessalit        70.0      ML 2019-08-24 13:46:40      29.0
# ..                ...         ...     ...                 ...       ...
# 530           bubaque        50.0      GW 2019-08-24 13:48:32      83.0
# 531  villa carlos paz         0.0      AR 2019-08-24 13:48:32      37.0
# 532            nyurba        30.0      RU 2019-08-24 13:48:32      95.0
# 533          naantali         0.0      FI 2019-08-24 13:48:32      76.0
# 534           gigmoto       100.0      PH 2019-08-24 13:48:33      79.0
# 535            blythe        20.0      US 2019-08-24 13:48:33      46.0
# 536        burns lake        77.0      CA 2019-08-24 13:48:33      58.0
# 537           dunedin        93.0      NZ 2019-08-24 13:46:48      34.0
# 538           iralaya        40.0      HN 2019-08-24 13:48:34      66.0
# 539        gosainganj        75.0      IN 2019-08-24 13:48:34      94.0
# 540            niamey        40.0      NE 2019-08-24 13:48:34      58.0
# 541          dongfeng         4.0      CN 2019-08-24 13:48:34      94.0
# 542          lorengau        98.0      PG 2019-08-24 13:48:34      84.0
# 543            sokoni        22.0      CD 2019-08-24 13:48:35      38.0
# 544       saint-louis         1.0      SN 2019-08-24 13:48:35      80.0
# 545            beloha         7.0      MG 2019-08-24 13:48:35      75.0
# 546           magadan        51.0      RU 2019-08-24 13:48:35      95.0
# 547           gamboma        99.0      CG 2019-08-24 13:48:36      66.0
# 548           fortuna        20.0      US 2019-08-24 13:48:36      64.0
# 549           socorro         1.0      US 2019-08-24 13:48:36      42.0
# 550           cayenne        56.0      GF 2019-08-24 13:48:36      66.0
# 551      kudahuvadhoo        99.0      MV 2019-08-24 13:48:37      69.0
# 552          flinders         0.0      AU 2019-08-24 13:48:37      52.0
# 553        ust-ilimsk        97.0      RU 2019-08-24 13:48:37      96.0
# 554       alekseyevsk       100.0      RU 2019-08-24 13:48:38      96.0
# 555      batemans bay         0.0      AU 2019-08-24 13:48:38      79.0
# 556   lazaro cardenas        75.0      MX 2019-08-24 13:48:38      54.0
# 557              luau        83.0      CD 2019-08-24 13:48:39      22.0
# 558          sulangan       100.0      PH 2019-08-24 13:48:39      70.0
# 559     pacific grove         1.0      US 2019-08-24 13:48:39      53.0
#
#        Lat     Lng  Max Temp  Wind Speed
# 0   -34.42   19.24   66.9920    1.006623
# 1    63.86  -21.15   55.0040    9.171454
# 2   -22.97  -42.02   73.4000    9.171454
# 3    39.62  -77.74   78.0080    3.355410
# 4    70.62  147.90   54.1328    5.391025
# 5    25.21   64.64   80.4128    7.516118
# 6    77.48  -69.36   37.5728   27.380146
# 7    62.45 -114.38   53.6000    8.052984
# 8    39.95  -94.76   77.0000   17.224438
# 9    35.75  -95.37   86.0000    6.934514
# 10  -33.93   18.42   60.9980   17.224438
# 11  -35.17  173.16   51.0080   23.107590
# 12   39.47    3.15   80.9960    4.697574
# 13   52.47    1.45   78.8000    5.816044
# 14   69.44 -133.03   39.2000   17.224438
# 15  -23.12 -134.97   70.3328   20.960128
# 16   60.55 -151.26   60.0080    6.934514
# 17  -20.74  116.85   63.8528    7.113469
# 18  -21.21 -159.78   73.4000    4.697574
# 19   73.51   80.55   41.1728   12.705819
# 20   14.90  -24.50   78.2528   11.453133
# 21   25.60 -109.05   89.9960    5.816044
# 22   64.73  177.51   50.0000    4.473880
# 23   54.44  113.59   47.2928    0.380280
# 24  -35.55  138.62   46.0040    5.816044
# 25  -53.16  -70.91   44.6000    8.052984
# 26   -0.92  100.36   80.7728   14.294047
# 27   78.22   15.63   41.0000    9.171454
# 28  -28.95  153.24   46.4000    5.816044
# 29   20.20    1.01   96.6128   12.347909
# ..     ...     ...       ...         ...
# 530  11.28  -15.83   79.6928   18.141583
# 531 -31.42  -64.50   71.9960   17.224438
# 532  63.29  118.35   49.0928    2.393526
# 533  60.45   22.03   60.0080    4.697574
# 534  13.78  124.39   82.7528   13.622965
# 535  33.61 -114.59   95.0000   10.289924
# 536  54.23 -125.76   55.9328    9.909644
# 537 -45.87  170.50   53.9960    7.001622
# 538  15.00  -83.23   89.6000    9.171454
# 539  26.77   81.11   80.6000    2.236940
# 540  13.52    2.11   86.0000   12.750558
# 541  42.67  125.53   57.1928    1.565858
# 542  -2.02  147.27   80.0528    8.567480
# 543 -12.89   28.78   64.3928    6.666081
# 544  16.03  -16.50   80.0528   14.920390
# 545 -25.17   45.06   65.2928   14.651957
# 546  59.56  150.80   52.5128    6.330540
# 547  -1.87   15.88   79.6928    6.554234
# 548  40.60 -124.16   82.9940    5.816044
# 549  31.65 -106.30   87.9980    6.934514
# 550   4.94  -52.33   87.8000    8.052984
# 551   2.67   72.89   83.2928    7.806921
# 552 -34.58  150.85   60.0080    4.697574
# 553  57.96  102.73   51.9728    3.758059
# 554  57.84  108.35   57.7328    6.956883
# 555 -35.71  150.18   53.9960    4.004123
# 556  28.39 -105.62   87.9980    6.934514
# 557 -10.70   22.23   71.5928    1.051362
# 558  11.14  123.72   82.0328    8.433264
# 559  36.62 -121.92   84.9920    8.433264
#
# [560 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
TodayDate = datetime.today().strftime('%Y-%m-%d')
lat_vs_temp_plot = plt.scatter(weather_data_df['Lat'],weather_data_df['Max Temp'],marker='o',c='coral',edgecolor='black',s=25,alpha=0.75)
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'City Latitude vs Max Temperature on {TodayDate}')
plt.savefig('output_data/lat_vs_temp_plot.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
lat_vs_humidity_plot = plt.scatter(weather_data_df['Lat'],weather_data_df['Humidity'],marker='o',c='coral',edgecolor='black',s=25,alpha=0.75)
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'City Latitude vs Humidity on {TodayDate}')
plt.savefig('output_data/lat_vs_humidity_plot.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
lat_vs_cloudiness_plot = plt.scatter(weather_data_df['Lat'],weather_data_df['Cloudiness'],marker='o',c='coral',edgecolor='black',s=25,alpha=0.75)
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Latitude vs Cloudiness on {TodayDate}')
plt.savefig('output_data/lat_vs_cloudiness_plot.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
lat_vs_wind_plot = plt.scatter(weather_data_df['Lat'],weather_data_df['Wind Speed'],marker='o',c='coral',edgecolor='black',s=25,alpha=0.75)
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'City Latitude vs Wind Speed on {TodayDate}')
plt.savefig('output_data/lat_vs_wind_plot.png')
plt.show()

# %% [markdown]
# Trend 1: As seen in the latitude vs max temp plot, lower latitudes have higher temperatures, and higher latitudes have lower temperatures.  This is because higher latitude areas receive the sun's rays at a lower angle, causing the same amount of light energy to be spread across a wider area.

# %%
lat_vs_temp_plot = plt.scatter(weather_data_df['Lat'],weather_data_df['Max Temp'],marker='o',c='coral',edgecolor='black',s=25,alpha=0.75)
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'City Latitude vs Max Temperature on {TodayDate}')
plt.show()

# %% [markdown]
# Trend 2: As also seen in the latitude vs max temp plot, the highest temperatures are centered around 20 degrees latitude, not zero. This is because it is currently summer in the northern hemisphere, which means that the tilt of the earth causes the north to more directly face the sun, so temperatures are higher in the north even holding the absolute latitude level constant.

# %%
lat_vs_cloudiness_plot = plt.scatter(weather_data_df['Humidity'],weather_data_df['Cloudiness'],marker='o',c='coral',edgecolor='black',s=25,alpha=0.75)
plt.grid()
plt.xlabel('Humidity (%)')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Humidity vs Cloudiness on {TodayDate}')
plt.show()

# %% [markdown]
# Trend 3: One can see that higher cloudiness tends to occur with higher humidity.  This is because clouds are made of water droplets in the air, and humidity measures the moisture in the air- so there should be a correlation.
